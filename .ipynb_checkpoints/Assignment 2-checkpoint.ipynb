# %%
pip install tensorflow
# Out:
# ...
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('survive.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare  ... Embarked WikiId  \
# 0      0         A/5 21171   7.2500  ...        S  691.0
# 1      0          PC 17599  71.2833  ...        C   90.0
# 2      0  STON/O2. 3101282   7.9250  ...        S  865.0
# 3      0            113803  53.1000  ...        S  127.0
# ...

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'WikiId', 'Name_wiki',
#        'Age_wiki', 'Hometown', 'Boarded', 'Destination', 'Lifeboat', 'Body',
#        'Class'],
#       dtype='object')

# %%
data.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305       NaN       3            Spector, Mr. Woolf    male
# 1305         1306       NaN       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307       NaN       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308       NaN       3           Ware, Mr. Frederick    male
# 1308         1309       NaN       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare  ... Embarked  WikiId  \
# 1304   NaN      0      0           A.5. 3236    8.0500  ...        S  1227.0
# 1305  39.0      0      0            PC 17758  108.9000  ...        C   229.0
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500  ...        S  1169.0
# 1307   NaN      0      0              359309    8.0500  ...        S  1289.0
# 1308   NaN      1      1                2668   22.3583  ...        C   702.0
#
#                                  Name_wiki Age_wiki  \
# ...

# %%
data.describe()
# Out:
#        PassengerId    Survived       Pclass          Age        SibSp  \
# count  1309.000000  891.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000    0.383838     2.294882    29.881138     0.498854
# std     378.020061    0.486592     0.837836    14.413493     1.041658
# min       1.000000    0.000000     1.000000     0.170000     0.000000
# 25%     328.000000    0.000000     2.000000    21.000000     0.000000
# 50%     655.000000    0.000000     3.000000    28.000000     0.000000
# 75%     982.000000    1.000000     3.000000    39.000000     1.000000
# max    1309.000000    1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare       WikiId     Age_wiki        Class
# count  1309.000000  1308.000000  1304.000000  1302.000000  1304.000000
# mean      0.385027    33.295479   658.534509    29.415829     2.291411
# std       0.865560    51.758668   380.377373    13.758954     0.840852
# ...

# %%
sns.relplot(x='Age', y='Survived', data=data)

# %%
data2 = pd.read_csv('estate agent.csv')

# %%
import matplotlib.pyplot as plt2

# %%
  
plt2.figure(figsize=(9,6))
 
plt2.bar(x= data['Sex'],
 
        height=data['Survived'])
 
plt2.xticks(rotation=45)
# Out:
# ([0, 1], [Text(0, 0, ''), Text(0, 0, '')])

# %%
plt2.figure(figsize=(9,6))
 
plt2.bar(x= data['Survived'],
 
        height=data['Age'])
 
plt2.xticks(rotation=45)
# Out:
# (array([-0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
data2.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
df = data2

# %%
df
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# ...

# %%
dataset = df.values

# %%
dataset
# Out:
# array([[ 8450,     7,     5, ...,     0,   548,     1],
#        [ 9600,     6,     8, ...,     1,   460,     1],
#        [11250,     7,     5, ...,     1,   608,     1],
#        ...,
#        [ 9042,     7,     9, ...,     2,   252,     1],
#        [ 9717,     5,     6, ...,     0,   240,     0],
#        [ 9937,     5,     6, ...,     0,   276,     0]], dtype=int64)

# %%
#splitting our dataset into input features (X) and (Y)
X = dataset[:,0:10]
Y = dataset[:,10]

# %%
#scales the dataset
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)

# %%
X_scale
# Out:
# array([[0.0334198 , 0.66666667, 0.5       , ..., 0.5       , 0.        ,
#         0.3864598 ],
#        [0.03879502, 0.55555556, 0.875     , ..., 0.33333333, 0.33333333,
#         0.32440056],
#        [0.04650728, 0.66666667, 0.5       , ..., 0.33333333, 0.33333333,
#         0.42877292],
#        ...,
#        [0.03618687, 0.66666667, 1.        , ..., 0.58333333, 0.66666667,
#         0.17771509],
#        [0.03934189, 0.44444444, 0.625     , ..., 0.25      , 0.        ,
#         0.16925247],
#        [0.04037019, 0.44444444, 0.625     , ..., 0.33333333, 0.        ,
#         0.19464034]])

# %%
from sklearn.model_selection import train_test_split
# splitting dataset
X_train, X_val_and_test, Y_train, Y_val_and_test = train_test_split(X_scale, Y, test_size=0.3)

# %%
X_val, X_test, Y_val, Y_test = train_test_split(X_val_and_test, Y_val_and_test, test_size=0.5)

# %%
#dimensions of the arrays
print(X_train.shape, X_val.shape, X_test.shape, Y_train.shape, Y_val.shape, Y_test.shape)
# Out:
# (1022, 10) (219, 10) (219, 10) (1022,) (219,) (219,)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
#specifying sequential model in our keras
model = Sequential([
    Dense(32, activation='relu', input_shape=(10,)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid'),
])

# %%
#calling the function model.compile
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#track accuracy
hist = model.fit(X_train, Y_train,
          batch_size=28, epochs=67,
          validation_data=(X_val, Y_val))
# Out:
# Epoch 1/67
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2787 - accuracy: 0.8865 - val_loss: 0.2637 - val_accuracy: 0.8950
# Epoch 2/67
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2776 - accuracy: 0.8875 - val_loss: 0.2599 - val_accuracy: 0.8995
# Epoch 3/67
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2777 - accuracy: 0.8885 - val_loss: 0.2616 - val_accuracy: 0.8995
# Epoch 4/67
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2768 - accuracy: 0.8885 - val_loss: 0.2607 - val_accuracy: 0.8995
# Epoch 5/67
# 37/37 [==============================] - 0s 3ms/step - loss: 0.2766 - accuracy: 0.8904 - val_loss: 0.2638 - val_accuracy: 0.8950
# Epoch 6/67
# 37/37 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8855 - val_loss: 0.2661 - val_accuracy: 0.8995
# Epoch 7/67
# ...

# %%
model.evaluate(X_test, Y_test)[1]
# Out:
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2566 - accuracy: 0.8950
# 0.8949771523475647

# %%
import matplotlib.pyplot as plt

# %%
#visualize the training loss and the validation loss.

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper right')
plt.show()
